# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv("CityOfPittsburgh-PlayGround.csv")

playground_in_neighborhood = dict()
neighborhood_playground_name = dict()

for row in range(data.shape[0]):
    neighborhood = data.iloc[row,7]
    playground_name = data.iloc[row,1]
    if neighborhood not in playground_in_neighborhood:
        playground_in_neighborhood[neighborhood] = 1                    #Keep count of the playgrounds in each neighborhood
        neighborhood_playground_name[neighborhood] = [playground_name]  #Map each neighborhood to a list of their playgrounds
    else:
        playground_in_neighborhood[neighborhood] += 1
        neighborhood_playground_name[neighborhood].append( playground_name )


print(neighborhood_playground_name)
print('\n')
print(playground_in_neighborhood)
# Out:
# {'Beechview': ['Able Long Playground', 'Alton Playground', 'Pauline Playground', 'Tropical Playground', 'Vanucci Playground'], 'Crawford-Roberts': ['Albert Graham Playground', 'August WIlson Playground', 'Granville Playground'], 'Central Northside': ['Alpine Playground', 'Jefferson Playground'], 'Bedford Dwellings': ['Ammon Playground'], 'South Side Slopes': ['Arlington Playground', 'Eleanor St. Playground', 'Monongahela Playground', 'Southside Playground', 'Winters Playground'], 'South Side Flats': ['Armstrong Playground', 'Ormsby Playground'], 'Lower Lawrenceville': ['Arsenal Playground'], 'Banksville': ['Banksville Playground'], 'Homewood North': ['Baxter Playground'], 'Bon Air': ['Bon Air Playground'], 'Central Oakland': ['Boundary Street Playground'], 'Brighton Heights': ['Brighton Heights Playground', 'Marmaduke Playground'], 'Brookline': ['Brookline Playground', 'Moore Playground'], 'Hazelwood': ['Bud Hammer Playground', 'Burgwin Playground', 'Lewis Playground'], 'Squirrel Hill South': ['Camp David Lawrence Playground', 'Davis Playground', 'Frick Beechwood Playground', 'Schenley Anderson Playground', 'Schenley Bartlett Playground', 'Schenley Oval Playground', 'Schenley Overlook Playground', "Vietnam Veteran's Playground"], 'Spring Garden': ['Catalono Playground'], 'Lincoln-Lemington-Belmar': ['Chadwick Playground', 'Paulson Playground'], 'Windgap': ['Chartiers Playground'], 'Troy Hill': ['Cowley Playground', 'Lookout Street Playground'], 'Westwood': ['Crafton Heights Playground'], 'Perry South': ['Cross and Strauss Playground'], 'Homewood West': ['Dallas Playground'], 'Allegheny Center': ['Deer Pit Playground', 'North Ave. Playground', 'Sue Murray Playground', 'Martin Luther King Playground'], 'Strip District': ['Denny Playground'], 'Stanton Heights': ['Dinan Playground'], 'Crafton Heights': ['Dunbar Playground', 'Stratmore Playground'], 'West Oakland': ['Dunseith Playground'], 'East Carnegie': ['East Carnegie Playground'], 'Duquesne Heights': ['Eileen McCoy Playground'], 'East Liberty': ['Enright Playground', 'Garland Playground'], 'Esplen': ['Esplen Playground'], 'Fairywood': ['Eric Guy Kelly Playground'], 'Highland Park': ['Farmhouse Playground', 'Highland Park Super Playground', 'Pool Grove Playground', 'Rhododendron Playground'], 'Upper Lawrenceville': ['Fifty-Seventh St Playground', 'McCandless Playground'], 'Fineview': ['Fineview Playground'], 'Regent Square': ['Forbes and Braddock Playground'], 'Garfield': ['Fort Pitt Playground', 'Nelson Mandela Playground'], 'Greenfield': ['Four Mile Run Playground', 'Magee Playground'], 'South Oakland': ['Frazier Playground', 'Lawn & Ophelia Playground', 'Niagara Playground'], 'Allentown': ['Grandview Playground'], 'Hays': ['Hays Playground'], 'Elliott': ['Herschel Playground', 'Townsend Playground', 'West End Playground'], 'Morningside': ["Heth's Playground", 'Joe Natoli Playground'], 'Terrace Village': ['Kennard Playground'], 'Larimer': ['Larimer Playground'], 'Carrick': ['Leolyn Playground', 'Phillips Playground', 'Phillips Lower Playground'], 'Central Lawrenceville': ['Leslie Playground'], 'Lincoln Place': ['Lincoln Place Playground', 'McBride Playground'], 'Manchester': ['Manchester Playground', 'McKnight Playground'], 'Marshall-Shadeland': ['Marshall-California Playground', 'Woods Run Playground'], 'Sheraden': ['McGonigle Playground', 'Mutual Playground', 'Sheraden Lower Playground', 'Sheraden Upper Playground'], 'Beltzhoover': ['Mckinley Bausman Playground', 'McKinley Playground', 'Warrington Playground'], 'Shadyside': ['Mellon Playground'], 'Mount Washington': ['Mt. Washington Playground', 'Olympia Playground', 'Ream Playground'], 'Oakwood': ['Oakwood Playground'], 'Bloomfield': ['Osceola Playground', 'Paul Sciullo Jr. Playground'], 'Perry North': ['Riverview Playground'], 'Upper Hill': ['Robert E. WIlliams Playground'], 'New Homestead': ['Roland Lockridge Playground'], 'Spring Hill-City View': ['Spring Hill Playground'], 'Swisshelm Park': ['Swisshelm Playground'], 'B ...
#
#
# {'Beechview': 5, 'Crawford-Roberts': 3, 'Central Northside': 2, 'Bedford Dwellings': 1, 'South Side Slopes': 5, 'South Side Flats': 2, 'Lower Lawrenceville': 1, 'Banksville': 1, 'Homewood North': 1, 'Bon Air': 1, 'Central Oakland': 1, 'Brighton Heights': 2, 'Brookline': 2, 'Hazelwood': 3, 'Squirrel Hill South': 8, 'Spring Garden': 1, 'Lincoln-Lemington-Belmar': 2, 'Windgap': 1, 'Troy Hill': 2, 'Westwood': 1, 'Perry South': 1, 'Homewood West': 1, 'Allegheny Center': 4, 'Strip District': 1, 'Stanton Heights': 1, 'Crafton Heights': 2, 'West Oakland': 1, 'East Carnegie': 1, 'Duquesne Heights': 1, 'East Liberty': 2, 'Esplen': 1, 'Fairywood': 1, 'Highland Park': 4, 'Upper Lawrenceville': 2, 'Fineview': 1, 'Regent Square': 1, 'Garfield': 2, 'Greenfield': 2, 'South Oakland': 3, 'Allentown': 1, 'Hays': 1, 'Elliott': 3, 'Morningside': 2, 'Terrace Village': 1, 'Larimer': 1, 'Carrick': 3, 'Central Lawrenceville': 1, 'Lincoln Place': 2, 'Manchester': 2, 'Marshall-Shadeland': 2, 'Sheraden': 4, 'Beltzhoover': 3, 'Shadyside': 1, 'Mount Washington': 3, 'Oakwood': 1, 'Bloomfield': 2, 'Perry North': 1, 'Upper Hill': 1, 'New Homestead': 1, 'Spring Hill-City View': 1, 'Swisshelm Park': 1, 'Bluff': 1, 'Middle Hill': 1, 'West End': 1, 'Polish Hill': 1, 'Point Breeze North': 1, 'Squirrel Hill North': 1}

# %%
plt.figure(figsize=(5,20))          #Set the size/width of the figure wider         
plt.style.use('classic')            #Set the style of the bar chart to classic
plt.barh(list(playground_in_neighborhood.keys()), list(playground_in_neighborhood.values())) #Create a horizontal bar chart of the neighborhoods and the number of playgrounds
plt.title("Playgrounds in Pittsburgh Neighborhood")
plt.ylabel("Neighborhood")
plt.xlabel("Number of Playgrounds")
# Out:
# Text(0.5,0,'Number of Playgrounds')

# %%
#Create a data frame of Pittsburgh neighborhoods and the number of playgrounds in each neighborhood
data_subset = pd.DataFrame(list(playground_in_neighborhood.values()),index=list(playground_in_neighborhood.keys()),columns=['Count'])
pd.set_option('display.max_colwidth', 250)                      #Set maximum column width to fit all data
data_subset.insert(1, 'Playgrounds', neighborhood_playground_name.values()) #Insert a column for the names of the playgrounds
data_subset.head(20)
# Out:
#                           Count  \
# Beechview                     5
# Crawford-Roberts              3
# Central Northside             2
# Bedford Dwellings             1
# South Side Slopes             5
# South Side Flats              2
# Lower Lawrenceville           1
# Banksville                    1
# Homewood North                1
# Bon Air                       1
# Central Oakland               1
# Brighton Heights              2
# Brookline                     2
# Hazelwood                     3
# Squirrel Hill South           8
# Spring Garden                 1
# Lincoln-Lemington-Belmar      2
# Windgap                       1
# Troy Hill                     2
# Westwood                      1
#
#                                                                                                                                                                                                                                                Playgrounds
# Beechview                                                                                                                                            [Able Long Playground, Alton Playground, Pauline Playground, Tropical Playground, Vanucci Playground]
# Crawford-Roberts                                                                                                                                                                [Albert Graham Playground, August WIlson Playground, Granville Playground]
# Central Northside                                                                                                                                                                                                [Alpine Playground, Jefferson Playground]
# Bedford Dwellings                                                                                                                                                                                                                       [Ammon Playground]
# South Side Slopes                                                                                                                         [Arlington Playground, Eleanor St. Playground, Monongahela Playground, Southside Playground, Winters Playground]
# South Side Flats                                                                                                                                                                                                 [Armstrong Playground, Ormsby Playground]
# Lower Lawrenceville                                                                                                                                                                                                                   [Arsenal Playground]
# Banksville                                                                                                                                                                                                                         [Banksville Playground]
# Homewood North                                                                                                                                                                                                                         [Baxter Playground]
# Bon Air                                                                                                                                                                                                                               [Bon Air Playground]
# Central Oakland                                                                                                                                                                                                               [Boundary Street Playground]
# Brighton Heights                                                                                                                                                                                       [Brighton Heights Playground, Marmaduke Playground]
# Brookline                                                                                                                                                                                                         [Brookline Playground, Moore Playground]
# Hazelwood                                                                                                                                                                                    [Bud Hammer Playground, Burgwin Playground, Lewis Playground]
# Squirrel Hill South       [Camp David Lawrence Playground, Davis Playground, Frick Beechwood Playground, Schenley Anderson Playground, Schenley Bartlett Playground, Schenley Oval Playground, Schenley Overlook Playground, Vietnam Veteran's Playground]
# Spring Garden                                                                                                                                                                                                                        [Catalono Playground]
# Lincoln-Lemington-Belmar                                                                                                                                                                                         [Chadwick Playground, Paulson Playground]
# Windgap                                                                                                                                                                                                                             [Chartiers Playground]
# Troy Hill                                                                                                                                                                                                   [Cowley Playground, Lookout Street Playground]
# Westwood                                                                                                                                                                                                                      [Crafton Heights Playground]
